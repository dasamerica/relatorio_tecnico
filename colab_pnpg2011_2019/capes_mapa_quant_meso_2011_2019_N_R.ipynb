# %%
#Exemplo: https://medium.com/@louisartur53/an%C3%A1lise-e-visualiza%C3%A7%C3%A3o-espacial-de-dados-reais-em-python-com-folium-cd4650fc5930
#Exemplo: https://stackoverflow.com/questions/65042654/how-to-add-categorical-legend-to-python-folium-map 
try:
  import geopandas
except:
  # !pip install geopandas



import folium
import pandas as pd
import geopandas as gpd
import json

import os
import time


try:
  import selenium
except:
  # !pip install selenium

from selenium import webdriver

import branca

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin


br_meso = 'sample_data/mesorregiao.json'
geo_json_data = json.load(open(br_meso))
nil = gpd.read_file(br_meso)

mapa = folium.Map(
    width=800, height=600,
    location=[-16.1237611, -59.9219642], 
    tiles='http://tile.stamen.com/toner-lite/{z}/{x}/{y}.png ', 
    attr="toner-bcg",
    zoom_start=4
)
folium.GeoJson(geo_json_data).add_to(mapa)

programas_br = pd.read_csv('sample_data/rea_2019_MP_T.csv')

programas_br.rename(columns={
    'MESO': 'id', 
    'QTY': 'qty'}, inplace=True)

programas_br_out_3000=programas_br
programas_br_out_3000=programas_br_out_3000[programas_br_out_3000['qty'] >= 1200]
programas_br_out_3000=programas_br_out_3000[programas_br_out_3000['qty'] <= 3000]

programas_br_out_M3000=programas_br
programas_br_out_M3000=programas_br_out_M3000[programas_br_out_M3000['qty'] > 3000]


programas_br_out_3000.rename(columns={
    'id': 'MESO'}, inplace=True)
NIL_programas_br_out_3000=nil.merge(programas_br_out_3000,on="MESO")

programas_br_out_M3000.rename(columns={
    'id': 'MESO'}, inplace=True)
NIL_programas_br_out_M3000=nil.merge(programas_br_out_M3000,on="MESO")




programas_br=programas_br[programas_br['qty'] < 1200]



#Escala programas
#myscale = (programas_br['qty'].quantile((0,0.45,0.67,0.78,0.89,0.96,1))).tolist()
#myscale = [1,15,50,100,150,464]

#Escala para discentes matriculados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 500, 1000, 5000, 10000, 35000]

#Escala para discentes titulados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 200, 1000,1500, 2000, 5000, 11000]


#Escala para discentes matriculados 2011
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 500, 1000, 5000, 10000, 35000]

#Escala para discentes titulados 2011
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 200, 1000,1500, 2000, 5000, 11000]

#Escala para discentes doutorado academico matriculados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 600, 1600, 3000, 8000, 16000]

#Escala para discentes doutorado academico titulados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 120, 350, 600, 800, 3500]

#Escala para discentes doutorado profissional  2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 600, 1600, 3000, 8000, 16000]

#Escala para discentes mestrado academico matriculados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 1000, 2500, 4000, 5500, 7000, 16000]


#Escala para discentes mestrado academico titulados 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 350, 800, 1500, 3000, 4500, 6000]

#Escala para discentes mestrado profissional matriculado 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 500, 1000, 2000, 3000, 4500, 6000]

#Escala para discentes mestrado profissional titulado 2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [5, 100, 200, 300, 400, 1000, 2000]

#Escala para discentes doutorado academico matriculados/titulados 2011
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 500, 1500, 2500, 3500, 7000, 13000]
#myscale = [1, 100, 250, 400, 600, 1500, 2500]

#Escala para discentes mestrado academico matriculados/titulados 2011
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 600, 2000, 3500, 5000, 7000, 10000, 15000]
#myscale = [1, 200, 700, 1000, 1500, 2500, 5100]

#Escala para discentes mestrado ´profissional matriculados/titulados 2011
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 100, 250, 450, 700, 1000, 1500, 3000]
#myscale = [1, 200, 700, 1000, 1500, 2500, 5100]

#Escala para discentes doutorado profissional  2018
#myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
#myscale = [1, 600, 1600, 3000, 8000, 16000]



#### Escala única ###
myscale = [1, 1000, 2500, 4000, 5500, 7000, 16000]
myscale = (programas_br['qty'].quantile(([0, 0.5, 0.75, 0.85, 0.9, 1]))).tolist()
myscale = [1, 100, 200, 400, 600, 800, 1000, 1200]

#https://matplotlib.org/2.0.2/examples/color/colormaps_reference.html

folium.Choropleth(
    geo_data=geo_json_data,
    name='Mesorregioes',
    data=programas_br,
    columns=['id','qty'],
    key_on='feature.properties.MESO',
#    fill_color='YlGnBu',
#    fill_color='BuPu',
#    fill_color='YlGnBu',
#    fill_color='YlOrBr',
    fill_color='YlOrRd',
    threshold_scale=myscale,
#    control_scale=True,
    fill_opacity=1,
    line_opacity=1,
    line_color='black',
    line_weight=1,
    outer_line_color='green',
    legend_name='quantidade de discentes da pós-graduação',
    legend_kwds={'shrink': 0.3},
    smooth_factor=1,
    nan_fill_color = 'lightgray',
    nan_fill_opacity=1
    #    binning_endpoints=[10,50,100,150,200,250,300,350,400,450,500]
).add_to(mapa)


if (not NIL_programas_br_out_3000.empty):
  style_function = lambda x: {'fillColor': '#00ff00', 
                            'color':'#00ff00', 
                            'fillOpacity': 1.0, 
                            'weight': 0.1
                            }
  highlight_function = lambda x: {'fillColor': '#00ff00', 
                                'color':'#00ff00', 
                                'fillOpacity': 1.0, 
                               'weight': 0.1
                                }

  NIL_programas_3000 = folium.features.GeoJson(
    NIL_programas_br_out_3000,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function
  )
  mapa.add_child(NIL_programas_3000)
  mapa.keep_in_front(NIL_programas_3000)

if (not NIL_programas_br_out_M3000.empty):
  style_function = lambda x: {'fillColor': '#0000ff', 
                            'color':'#0000ff', 
                            'fillOpacity': 1.0, 
                            'weight': 0.1
                            }
  highlight_function = lambda x: {'fillColor': '#0000ff', 
                                'color':'#0000ff', 
                                'fillOpacity': 1.0, 
                               'weight': 0.1
                                }

  NIL_programas_M3000 = folium.features.GeoJson(
    NIL_programas_br_out_M3000,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function
  )
  mapa.add_child(NIL_programas_M3000)
  mapa.keep_in_front(NIL_programas_M3000)

#colorhexa.com
legend_html = '''
{% macro html(this, kwargs) %}
<div style="
    position: fixed; 
    bottom: 10px;
    right: 10px;
    width: 250px;
    height: 150px;
    z-index:9999;
    font-size:12px;
    ">
    <p><a style="color:#808080;font-size:200%;margin-left:20px;">&diams;</a>&emsp;Sem programa </p>
    <p><a style="color:#00ff00;font-size:200%;margin-left:20px;">&diams;</a>&emsp;De 1200 a 3000 titulados</p>
    <p><a style="color:#0000ff;font-size:200%;margin-left:20px;">&diams;</a>&emsp;De 3000 a 6000 titulados</p>

</div>
<div style="
    position: fixed; 
    bottom: 10px;
    right: 10px;
    width: 250px;
    height: 150px; 
    z-index:9998;
    font-size:12px;
    background-color: #ffffff;

    opacity: 0.7;
    ">
</div>
{% endmacro %}
'''
legend = branca.element.MacroElement()
legend._template = branca.element.Template(legend_html)



folium.LayerControl().add_to(mapa)
mapa.get_root().add_child(legend)
fn = 'sample_data/rea_2019_MP_T.html'
mapa.save(fn)
#mapa


delay = 5
time.sleep(delay)
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-application-cache')
tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
# open it, go to a website, and get results
browser = webdriver.Chrome('chromedriver',options=options)
browser.get(tmpurl)
#Give the map tiles some time to load
time.sleep(delay)
browser.save_screenshot('rea_2019_MP_T.png')
browser.delete_all_cookies
browser.quit()
# Out:
# ...
#      |████████████████████████████████| 1.0MB 6.4MB/s
# ...
#      |████████████████████████████████| 6.5MB 15.4MB/s
# ...
#      |████████████████████████████████| 15.3MB 252kB/s
# ...
#      |████████████████████████████████| 911kB 5.1MB/s
# ...
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# ...
